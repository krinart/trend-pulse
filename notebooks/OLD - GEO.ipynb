# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')
    
from config import ALL_LOCATIONS
import generation
import map_utils
    
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, Polygon, LineString
from shapely.ops import unary_union
import matplotlib.pyplot as plt
import json
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/viktor/workspace/ds2/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Read a shapefile
geo_data_all_df = gpd.read_file("../data/500Cities_City_11082016/CityBoundaries.shp")
geo_data_all_df.head()
# Out:
#        NAME CLASS  ST STFIPS PLACEFIPS  POP2010 STPLFIPS  \
# 0     Pharr  city  TX     48     57200    70400  4857200
# 1   McAllen  city  TX     48     45384   129877  4845384
# 2  Edinburg  city  TX     48     22660    77100  4822660
# 3    Laredo  city  TX     48     41464   236091  4841464
# 4   Mission  city  TX     48     48768    77058  4848768
#
#                                             geometry
# 0  POLYGON ((-10929531.239 3029892.718, -10929486...
# 1  POLYGON ((-10934477.721 3037591.957, -10934450...
# 2  POLYGON ((-10924696.742 3050068.459, -10924700...
# 3  POLYGON ((-11090500.378 3205304.554, -11090391...
# 4  POLYGON ((-10946610.1 3030967.743, -10946347.6...

# %%
locations_df = pd.DataFrame(ALL_LOCATIONS)
locations_df.head()
# Out:
#    id      lat       lon         name state      region  \
# 0   1  32.7157 -117.1611    San Diego    CA  California
# 1   2  34.0522 -118.2437  Los Angeles    CA  California
# 2   3  37.7749 -122.4194     Bay Area    CA  California
# 3   4  28.5384  -81.3789      Orlando    FL     Florida
# 4   5  25.7617  -80.1918        Miami    FL     Florida
#
#                                               cities
# 0  [San Diego, El Cajon, Chula Vista, Escondido, ...
# 1  [Los Angeles, Burbank, Santa Monica, Glendale,...
# 2  [San Francisco, Oakland, Milpitas, Mountain Vi...
# 3                                          [Orlando]
# 4  [Miami, Miami Beach, Hialeah, Miami Gardens, H...

# %%
cities = []
    
# Iterate through each area in config
for location in ALL_LOCATIONS:
    # For each city in the area's cities list, create a pair with the state
    for city in location.cities:
        cities.append({
            'city': city,
            'state': location.state,
            'location': location.name,
            'location_id': location.id,
            'region': location.region,
        })

# Convert to DataFrame
cities_df = pd.DataFrame(cities)
cities_df.head()
# Out:
#           city state   location  location_id      region
# 0    San Diego    CA  San Diego            1  California
# 1     El Cajon    CA  San Diego            1  California
# 2  Chula Vista    CA  San Diego            1  California
# 3    Escondido    CA  San Diego            1  California
# 4    Oceanside    CA  San Diego            1  California

# %%
cities_geo_df = geo_data_all_df.merge(
    cities_df, how='inner', left_on=['NAME','ST'], right_on = ['city','state']
)[['city', 'state', 'geometry', 'location', 'location_id', 'region', 'POP2010']]
cities_geo_df.rename(columns={"POP2010": "population"}, inplace=True)
cities_geo_df.head()
# Out:
#           city state                                           geometry  \
# 0  San Antonio    TX  MULTIPOLYGON (((-10961926.119 3407333.744, -10...
# 1       Austin    TX  MULTIPOLYGON (((-10861676.106 3548126.409, -10...
# 2      Houston    TX  MULTIPOLYGON (((-10601763.841 3450638.449, -10...
# 3      Orlando    FL  MULTIPOLYGON (((-9053370.515 3298107.956, -905...
# 4    Hollywood    FL  MULTIPOLYGON (((-8924847.554 3005004.953, -892...
#
#       location  location_id          region  population
# 0  San Antonio           20  Texas Triangle     1327407
# 1       Austin           17  Texas Triangle      790390
# 2      Houston           19  Texas Triangle     2099451
# 3      Orlando            4         Florida      238300
# 4        Miami            5         Florida      140768

# %%
CITIES_INFO = {}
for _, row in cities_geo_df.iterrows():
    CITIES_INFO[(row.city, row.state)] = {
        'geometry': row.geometry,
        'population': row.population
    }

# %%
local_area_df = cities_geo_df.groupby(['location', 'region', 'state'])['geometry'].apply(unary_union).to_frame().reset_index()
local_area_df.head()
# Out:
#     location              region state  \
# 0     Austin      Texas Triangle    TX
# 1  Baltimore  Northeast Corridor    MD
# 2   Bay Area          California    CA
# 3     Boston  Northeast Corridor    MA
# 4    Chicago         Great Lakes    IL
#
#                                             geometry
# 0  MULTIPOLYGON (((-10872647.984 3564027.856, -10...
# 1  MULTIPOLYGON (((-8523466.151 4752515.705, -852...
# 2  MULTIPOLYGON (((-13627218.684 4552503.028, -13...
# 3  MULTIPOLYGON (((-7909405.847 5202635.152, -790...
# 4  POLYGON ((-9758837.384 5164420.691, -9758834.9...

# %%
map_utils.display_geometry_on_map(local_area_df[local_area_df['location'] == 'Seattle']['geometry'].iloc[0])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89e985d06d3945b957be6eb44840447b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89e985d06d3945b957be6eb44840447b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89e985d06d3945b957be6eb44840447b = L.map(
#                 &quot;map_89e985d06d3945b957be6eb44840447b&quot;,
#                 {
#                     center: [47.562421062691115, -122.25793737253133],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58f841ffb543ad970f166e2fa766b482 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_58f841ffb543ad970f166e2fa766b482.addTo(map_89e985d06d3945b957be6eb44840447b);
#
#
#         function geo_json_22184dc746fa7a4acc749931c9bf9ed4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3388ff&quot;, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_22184dc746fa7a4acc749931c9bf9ed4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_22184dc746fa7a4acc749931c9bf9ed4 = L.geoJson(null, {
#                 onEachFeature: geo_json_22184dc746fa7a4acc749931c9bf9ed4_onEachFeature,
#
#                 style: geo_json_22184dc746fa7a4acc749931c9bf9ed4_styler,
#         });
#
#         function geo_json_22184dc746fa7a4acc749931c9bf9ed4_add (data) {
#             geo_json_22184dc746fa7a4acc749931c9bf9ed4
#                 .addData(data);
#         }
#             geo_json_22184dc746fa7a4acc749931c9bf9ed4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[